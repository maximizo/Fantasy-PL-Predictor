# %%
import requests
import pandas as pd
import numpy as np

# %%
#import non-fantasy player data
players_2019 = "api/data/resources/playerdata_201920.csv"

# %%
#Preview data
pd.read_csv(players_2019).head(5)
# Out:
#                 full_name  age   birthday          league     season  \
# 0  Aaron Anthony Connolly   20  949017600  Premier League  2019/2020
# 1         Aaron Cresswell   31  629683200  Premier League  2019/2020
# 2            Aaron Lennon   33  545529600  Premier League  2019/2020
# 3              Aaron Mooy   30  653356800  Premier League  2019/2020
# 4          Aaron Ramsdale   22  895104000  Premier League  2019/2020
#
#      position            Current Club  minutes_played_overall  \
# 0     Forward  Brighton & Hove Albion                    1262
# 1    Defender         West Ham United                    2730
# 2  Midfielder                 Burnley                     485
# 3  Midfielder  Brighton & Hove Albion                    2090
# 4  Goalkeeper         AFC Bournemouth                    3330
#
#    minutes_played_home  minutes_played_away  ... conceded_per_90_overall  \
# 0                  592                  670  ...                    1.50
# ...

# %%
#identify player (using Mesut Ozil 37605 as an example)
#player_id = '37605'
#player_index = player
#select all players
#for player_index in range (1,6):
 #   print(player_index)

# %%
#player_id = '37605'
player_dict = {}
#select all players
i = 0
for player_index in range (1,640):
    player_dict[player_index] = requests.get('https://fantasy.premierleague.com/api/element-summary/'+str(player_index)+'/')
    player_list.append(player_dict)
    i += 1

# %%
player_list_df = pd.DataFrame(player_dict)
player_list_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-a9dde4d1d3e1> in <module>
# ----> 1 player_list_df = pd.DataFrame(player_dict)
#       2 player_list_df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ...

# %%
print(player_dict[i].content)
# Out:
# b'{"fixtures":[{"id":207,"code":2128494,"team_h":18,"team_h_score":null,"team_a":8,"team_a_score":null,"event":21,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-01-30T15:00:00Z","event_name":"Gameweek 21","is_home":true,"difficulty":2},{"id":214,"code":2128501,"team_h":15,"team_h_score":null,"team_a":18,"team_a_score":null,"event":22,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-02-02T18:00:00Z","event_name":"Gameweek 22","is_home":false,"difficulty":2},{"id":227,"code":2128514,"team_h":17,"team_h_score":null,"team_a":18,"team_a_score":null,"event":23,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-02-06T15:00:00Z","event_name":"Gameweek 23","is_home":false,"difficulty":4},{"id":237,"code":2128524,"team_h":18,"team_h_score":null,"team_a":13,"team_a_score":null,"event":24,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-02-13T15:00:00Z","event_name":"Ga
# ...

# %%
#convert player_index integer to string
player_int = str(player_index)
print(player_int)
# Out:
# 4

# %%
#import fantasy api url for past seasons stats per player
player_url = 'https://fantasy.premierleague.com/api/element-summary/'+player_int+'/'

# %%
#get request from api endpoint
r = requests.get(player_url)
#transform into json object
json = r.json()
#preview json keys
json.keys()
# Out:
# dict_keys(['fixtures', 'history', 'history_past'])

# %%
#create dataframes using the 3 keys
#history_past_df = pd.DataFrame(json['history_past'])
#fixtures_df = pd.DataFrame(json['fixtures'])
#history_df = pd.DataFrame(json['history'])

# %%
#preview dataframes - looks like history_past_df will give us info for previous seasons
#history_past_df
#fixtures_df.head()
#history_df
json
# Out:
# {'fixtures': [{'id': 199,
#    'code': 2128486,
#    'team_h': 1,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 21,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2021-01-30T17:30:00Z',
#    'event_name': 'Gameweek 21',
#    'is_home': True,
#    'difficulty': 4},
#   {'id': 215,
#    'code': 2128502,
#    'team_h': 20,
#    'team_h_score': None,
#    'team_a': 1,
#    'team_a_score': None,
#    'event': 22,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2021-02-02T18:00:00Z',
#    'event_name': 'Gameweek 22',
#    'is_home': False,
#    'difficulty': 3},
#   {'id': 219,
#    'code': 2128506,
#    'team_h': 2,
#    'team_h_score': None,
#    'team_a': 1,
#    'team_a_score': None,
#    'event': 23,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2021-02-06T12:30:00Z',
# ...

# %%
player_list = []
i = 0
for player in json['history_past']:
    element_code = json['history_past'][i]['element_code']
    player_list
    i += 1

# %%
json['history_past'][0]['element_code']
for i in range(0,10): 
    print(json['history_past'][i]['element_code'])
# Out:
# 54694
# 54694
# 54694
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-111-eb090e0edc3d> in <module>
#       1 json['history_past'][0]['element_code']
#       2 for i in range(0,10):
# ----> 3     print(json['history_past'][i]['element_code'])
#       4
#
# IndexError: list index out of range

# %%
json_df = pd.DataFrame(player_list)
json_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
####NOTES####
#create dataframes using the 3 keys
#history_past_df = pd.DataFrame(json['history_past'])
#fixtures_df = pd.DataFrame(json['fixtures'])
#history_df = pd.DataFrame(json['history'])
#preview dataframes - looks like history_past_df will give us info for previous seasons
#history_past_df
#fixtures_df.head()
#history_df
json = r.json()
#preview json keys
json.keys()
# Out:
# dict_keys(['events', 'game_settings', 'phases', 'teams', 'total_players', 'elements', 'element_stats', 'element_types'])

# %%
#import fantasy api url with current data 
data_url = 'https://fantasy.premierleague.com/api/bootstrap-static/'
#get request from api endpoint
r = requests.get(data_url)
#transform into json object
json = r.json()
#preview json keys
json.keys()
# Out:
# dict_keys(['events', 'game_settings', 'phases', 'teams', 'total_players', 'elements', 'element_stats', 'element_types'])

# %%
#create dataframe
elements_df = pd.DataFrame(json['elements'])
elements_df
# Out:
#      chance_of_playing_next_round  chance_of_playing_this_round    code  \
# 0                             0.0                           0.0   37605
# 1                             0.0                           0.0   39476
# 2                           100.0                         100.0   41270
# 3                            75.0                         100.0   54694
# 4                           100.0                         100.0   58822
# ..                            ...                           ...     ...
# 637                           NaN                           NaN  481626
# 638                           NaN                           NaN  448487
# 639                           NaN                           NaN  209353
# 640                           NaN                           NaN  465551
# 641                           NaN                           NaN   73314
#
#      cost_change_event  cost_change_event_fall  cost_change_start  \
# ...
