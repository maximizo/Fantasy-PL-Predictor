# %%
import requests
import pandas as pd
import numpy as np

# %%
#import non-fantasy player data
players_2019 = "api/data/resources/playerdata_201920.csv"

# %%
#Preview data
pd.read_csv(players_2019).head(5)
# Out:
#                 full_name  age   birthday          league     season  \
# 0  Aaron Anthony Connolly   20  949017600  Premier League  2019/2020
# 1         Aaron Cresswell   31  629683200  Premier League  2019/2020
# 2            Aaron Lennon   33  545529600  Premier League  2019/2020
# 3              Aaron Mooy   30  653356800  Premier League  2019/2020
# 4          Aaron Ramsdale   22  895104000  Premier League  2019/2020
#
#      position            Current Club  minutes_played_overall  \
# 0     Forward  Brighton & Hove Albion                    1262
# 1    Defender         West Ham United                    2730
# 2  Midfielder                 Burnley                     485
# 3  Midfielder  Brighton & Hove Albion                    2090
# 4  Goalkeeper         AFC Bournemouth                    3330
#
#    minutes_played_home  minutes_played_away  ... conceded_per_90_overall  \
# 0                  592                  670  ...                    1.50
# 1                 1395                 1335  ...                    1.62
# 2                  225                  260  ...                    2.60
# 3                 1010                 1080  ...                    1.29
# 4                 1620                 1710  ...                    1.65
#
#    min_per_conceded_overall  min_per_match  min_per_card_overall  \
# 0                        60             53                     0
# 1                        56             88                   390
# 2                        35             30                   121
# 3                        70             67                   697
# 4                        55             90                     0
#
#    min_per_assist_overall  cards_per_90_overall  rank_in_league_top_attackers  \
# 0                    1262                  0.00                            89
# 1                       0                  0.23                           151
# 2                       0                  0.74                           320
# 3                    1045                  0.13                           164
# 4                    3330                  0.00                           362
#
#    rank_in_league_top_midfielders  rank_in_league_top_defenders  \
# 0                             172                            -1
# 1                             260                           129
# 2                             402                            -1
# 3                             140                            -1
# 4                             248                           135
#
#    rank_in_club_top_scorer
# 0                        3
# 1                        6
# 2                       17
# 3                        8
# 4                       19
#
# [5 rows x 46 columns]

# %%
#identify player (using Mesut Ozil 37605 as an example)
#player_id = '37605'
#player_index = player
#select all players
#for player_index in range (1,6):
 #   print(player_index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e10212b76ea3> in <module>
#       1 #identify player (using Mesut Ozil 37605 as an example)
#       2 #player_id = '37605'
# ----> 3 player_index = player
#       4 #select all players
#       5 for player_index in range (1,6):
#
# NameError: name 'player' is not defined

# %%
#player_id = '37605'
player_dict = {}
#select all players
for player_index in range (1,640):
    player_dict[player_index] = requests.get('https://fantasy.premierleague.com/api/element-summary/'+str(player_index)+'/')

# %%
print(player_dict[638].content)
# Out:
# b'{"fixtures":[{"id":208,"code":2128495,"team_h":19,"team_h_score":null,"team_a":11,"team_a_score":null,"event":21,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-01-31T16:30:00Z","event_name":"Gameweek 21","is_home":true,"difficulty":4},{"id":209,"code":2128496,"team_h":2,"team_h_score":null,"team_a":19,"team_a_score":null,"event":22,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-02-03T20:15:00Z","event_name":"Gameweek 22","is_home":false,"difficulty":3},{"id":221,"code":2128508,"team_h":8,"team_h_score":null,"team_a":19,"team_a_score":null,"event":23,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-02-06T17:30:00Z","event_name":"Gameweek 23","is_home":false,"difficulty":2},{"id":238,"code":2128525,"team_h":19,"team_h_score":null,"team_a":15,"team_a_score":null,"event":24,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-02-13T15:00:00Z","event_name":"Gameweek 24","is_home":true,"difficulty":2},{"id":247,"code":2128534,"team_h":19,"team_h_score":null,"team_a":17,"team_a_score":null,"event":25,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-02-20T15:00:00Z","event_name":"Gameweek 25","is_home":true,"difficulty":4},{"id":254,"code":2128541,"team_h":12,"team_h_score":null,"team_a":19,"team_a_score":null,"event":26,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-02-27T12:30:00Z","event_name":"Gameweek 26","is_home":false,"difficulty":5},{"id":268,"code":2128555,"team_h":19,"team_h_score":null,"team_a":10,"team_a_score":null,"event":27,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-03-06T15:00:00Z","event_name":"Gameweek 27","is_home":true,"difficulty":2},{"id":275,"code":2128562,"team_h":13,"team_h_score":null,"team_a":19,"team_a_score":null,"event":28,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-03-13T15:00:00Z","event_name":"Gameweek 28","is_home":false,"difficulty":4},{"id":288,"code":2128575,"team_h":19,"team_h_score":null,"team_a":1,"team_a_score":null,"event":29,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-03-20T15:00:00Z","event_name":"Gameweek 29","is_home":true,"difficulty":3},{"id":298,"code":2128585,"team_h":20,"team_h_score":null,"team_a":19,"team_a_score":null,"event":30,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-04-03T14:00:00Z","event_name":"Gameweek 30","is_home":false,"difficulty":3},{"id":308,"code":2128595,"team_h":19,"team_h_score":null,"team_a":9,"team_a_score":null,"event":31,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-04-10T14:00:00Z","event_name":"Gameweek 31","is_home":true,"difficulty":4},{"id":316,"code":2128603,"team_h":14,"team_h_score":null,"team_a":19,"team_a_score":null,"event":32,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-04-17T14:00:00Z","event_name":"Gameweek 32","is_home":false,"difficulty":3},{"id":327,"code":2128614,"team_h":19,"team_h_score":null,"team_a":5,"team_a_score":null,"event":33,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-04-24T14:00:00Z","event_name":"Gameweek 33","is_home":true,"difficulty":4},{"id":330,"code":2128617,"team_h":4,"team_h_score":null,"team_a":19,"team_a_score":null,"event":34,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-05-01T14:00:00Z","event_name":"Gameweek 34","is_home":false,"difficulty":2},{"id":347,"code":2128634,"team_h":19,"team_h_score":null,"team_a":7,"team_a_score":null,"event":35,"finished":false,"minutes":0,"provisional_start_time":false,"kickoff_time":"2021-05-08T14:00:00Z","event_name":"Gameweek 35","is_home":true,"difficulty":3},{"id":349,"code":2128636,"team_h":3,"team_h_score":null,"team_a":19,"team_a_score":null,"event":36,"finished":false,"minutes":0,"provisional_star ...

# %%
#convert player_index integer to string
player_int = str(player_index)
print(player_int)
# Out:
# 639

# %%
#import fantasy api url for past seasons stats per player
#player_url = 'https://fantasy.premierleague.com/api/element-summary/'+player_int+'/'
player_url = 'https://fantasy.premierleague.com/api/element-summary/4/'

# %%
#get request from api endpoint
r = requests.get(player_url)
#transform into json object
json = r.json()
#preview json keys
json.keys()
# Out:
# dict_keys(['fixtures', 'history', 'history_past'])

# %%
#create dataframes using the 3 keys
history_past_df = pd.DataFrame(json['history_past'])
fixtures_df = pd.DataFrame(json['fixtures'])
history_df = pd.DataFrame(json['history'])

# %%
#preview dataframes - looks like history_past_df will give us info for previous seasons
history_past_df
#fixtures_df.head()
#history_df
# Out:
#   season_name  element_code  start_cost  end_cost  total_points  minutes  \
# 0     2017/18         54694         105       108            87     1056
# 1     2018/19         54694         110       108           205     2722
# 2     2019/20         54694         110       109           205     3136
#
#    goals_scored  assists  clean_sheets  goals_conceded  ...  penalties_missed  \
# 0            10        4             4              15  ...                 1
# 1            22        7             7              42  ...                 1
# 2            22        5            10              44  ...                 0
#
#    yellow_cards  red_cards  saves  bonus  bps  influence  creativity  threat  \
# 0             0          0      0     12  354      484.0       207.1   580.0
# 1             0          0      0     32  756      984.4       484.6  1429.0
# 2             3          1      0     37  807     1006.0       479.6  1369.0
#
#   ict_index
# 0     127.1
# 1     289.6
# 2     285.2
#
# [3 rows x 22 columns]

# %%
#import fantasy api url with current data 
data_url = 'https://fantasy.premierleague.com/api/bootstrap-static/'
#get request from api endpoint
r = requests.get(data_url)
#transform into json object
json = r.json()
#preview json keys
json.keys()
# Out:
# dict_keys(['events', 'game_settings', 'phases', 'teams', 'total_players', 'elements', 'element_stats', 'element_types'])

# %%
#create dataframe
elements_df = pd.DataFrame(json['elements'])
elements_df
# Out:
#      chance_of_playing_next_round  chance_of_playing_this_round    code  \
# 0                             0.0                           0.0   37605
# 1                             0.0                           0.0   39476
# 2                           100.0                         100.0   41270
# 3                            75.0                         100.0   54694
# 4                           100.0                         100.0   58822
# ..                            ...                           ...     ...
# 637                           NaN                           NaN  481626
# 638                           NaN                           NaN  448487
# 639                           NaN                           NaN  209353
# 640                           NaN                           NaN  465551
# 641                           NaN                           NaN   73314
#
#      cost_change_event  cost_change_event_fall  cost_change_start  \
# 0                    0                       0                 -3
# 1                    0                       0                 -2
# 2                    0                       0                 -1
# 3                    0                       0                 -7
# 4                    0                       0                 -4
# ..                 ...                     ...                ...
# 637                  0                       0                  0
# 638                  0                       0                  0
# 639                  0                       0                  0
# 640                  0                       0                  0
# 641                  0                       0                  0
#
#      cost_change_start_fall  dreamteam_count  element_type ep_next  ...  \
# 0                         3                0             3     0.0  ...
# 1                         2                0             2     0.0  ...
# 2                         1                0             2     3.3  ...
# 3                         7                1             3     4.9  ...
# 4                         4                0             2     3.5  ...
# ..                      ...              ...           ...     ...  ...
# 637                       0                0             2    -0.5  ...
# 638                       0                0             1    -0.5  ...
# 639                       0                0             4     0.5  ...
# 640                       0                0             2    -0.5  ...
# 641                       0                0             4     1.9  ...
#
#     threat_rank  threat_rank_type ict_index_rank ict_index_rank_type  \
# 0           641               257            641                 257
# 1           582               215            602                 219
# 2           251                77            298                  98
# 3            20                12             32                  22
# 4           400               151            387                 145
# ..          ...               ...            ...                 ...
# 637         460               180            509                 196
# 638         456                23            505                  53
# 639         396                61            464                  61
# 640         459               179            508                 195
# 641         642                84            642                  84
#
#      corners_and_indirect_freekicks_order  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 637                                   NaN
# 638                                   NaN
# 639                                   NaN
# 640                                   NaN
# 641                                   NaN
#
#      corners_and_indirect_freekicks_text direct_freekicks_order  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           4.0
# 3                                                           NaN
# 4                                                           NaN
# ..                                   ...                    ...
# 637                                                         NaN
# 638                                                         NaN
# 639                                                         NaN
# 640                                                         NaN
# 641                                                         NaN
#
#     direct_freekicks_text  penalties_order penalties_text
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      1.0
# 4                                      NaN
# ..                    ...              ...            ...
# 637                                    NaN
# 638                                    NaN
# 639                                    NaN
# 640                                    NaN
# 641                                    NaN
#
# [642 rows x 67 columns]
